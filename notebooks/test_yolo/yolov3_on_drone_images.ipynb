# %%
import sys
sys.path.append('../')

import utils

# %%
path = "../object-detection-opencv/test.jpg"
path = "/data/train"
path = utils.get_files_by_ext(path, ext=['jpg','png','jpeg'])[:10]
img = utils.image_to_matrix(path)

# %%
img[0].shape
# Out:
# (3, 416, 416)

# %%
utils.plot_image(img[5])
